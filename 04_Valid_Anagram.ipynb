# %% [markdown]
# <a href="https://colab.research.google.com/github/dkraynev/LeetCode/blob/main/04_Valid_Anagram.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Given two strings s and t, return true if t is an
# anagram of s, and false otherwise.

# %%
class Solution:
    def isAnagram(self, s: str, t: str) -> bool:
        """
        :type s: str
        :type t: str
        :rtype: bool
        """
        result = False
        if len(s) == len(t):
            for i in range(len(s)):
                if s[i] in t:
                    t = t.replace(s[i], "", 1)
                    result = True
                else:
                    result = False
                    break
        return result

# %%
s = "anagram"
t = "nagaram"
prov = Solution()
print(prov.isAnagram(s, t))


#Example 2:
s = "rat"
t = "car"
#Output: False

print(prov.isAnagram(s, t))
# Out:
# True
# False
