# %%
import pandas as pd

def nth_highest_salary(employee: pd.DataFrame, N: int) -> pd.DataFrame:
    salary = employee.drop_duplicates(subset='salary')
    salary = salary.sort_values(by='salary', ascending=False).reset_index()
    if len(salary) < N or N < 1:
        return pd.DataFrame({f'getNthHighestSalary({N})': [None]})
    salary = salary.rename(columns={'salary': f'getNthHighestSalary({N})'})
    return salary.loc[[N - 1], [f'getNthHighestSalary({N})']]
