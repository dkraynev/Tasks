# %% [markdown]
# <a href="https://colab.research.google.com/github/dkraynev/LeetCode/blob/main/500_Dataframes_with_pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
top3 = pd.read_csv('500_epa_ca_tx_pa.csv')
top3.head()
# Out:
#    state_code  state_name  county_code county_name   aqi
# 0           6  California            1     Alameda  11.0
# 1           6  California            7       Butte   6.0
# 2           6  California           19      Fresno  11.0
# 3           6  California           29        Kern   7.0
# 4           6  California           29        Kern   3.0

# %%
top3.shape
# Out:
# (546, 5)

# %%
top3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 546 entries, 0 to 545
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   state_code   546 non-null    int64
#  1   state_name   546 non-null    object
#  2   county_code  546 non-null    int64
#  3   county_name  546 non-null    object
#  4   aqi          546 non-null    float64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 21.5+ KB

# %%
top3.describe()
# Out:
#        state_code  county_code         aqi
# count  546.000000   546.000000  546.000000
# mean    20.593407    83.179487    8.906593
# std     19.001484    92.240873    9.078479
# min      6.000000     1.000000    0.000000
# 25%      6.000000    29.000000    3.000000
# 50%      6.000000    66.000000    6.000000
# 75%     42.000000    98.500000   11.000000
# max     48.000000   479.000000   93.000000

# %%
print(top3["state_name"].value_counts())
print()
print(top3["state_code"].value_counts())
# Out:
# state_name
# California      342
# Texas           104
# Pennsylvania    100
# Name: count, dtype: int64
#
# state_code
# 6     342
# 48    104
# 42    100
# Name: count, dtype: int64

# %%
top3_sorted = top3.sort_values(by="aqi", ascending=False)
top3_sorted.head()
# Out:
#      state_code  state_name  county_code    county_name   aqi
# 76            6  California           37    Los Angeles  93.0
# 146           6  California           37    Los Angeles  59.0
# 41            6  California           83  Santa Barbara  47.0
# 122           6  California           59         Orange  47.0
# 184           6  California           59         Orange  47.0

# %%
print(top3_sorted.iloc[10:13])
print()
print()
print(top3_sorted.iloc[:10])
print()
print()
print(top3_sorted.iloc[534:])
# Out:
#      state_code  state_name  county_code  county_name   aqi
# 186           6  California           73    San Diego  39.0
# 74            6  California           37  Los Angeles  38.0
# 189           6  California           85  Santa Clara  36.0
#
#
#      state_code  state_name  county_code    county_name   aqi
# 76            6  California           37    Los Angeles  93.0
# 146           6  California           37    Los Angeles  59.0
# 41            6  California           83  Santa Barbara  47.0
# 122           6  California           59         Orange  47.0
# 184           6  California           59         Orange  47.0
# 51           48       Texas          141        El Paso  47.0
# 80            6  California           65      Riverside  43.0
# 136          48       Texas          141        El Paso  40.0
# 58            6  California           65      Riverside  40.0
# 91           48       Texas          141        El Paso  40.0
#
#
# ...

# %%
mask = top3_sorted["state_name"] == "California"
ca_df = top3_sorted[mask]
print(ca_df.head())
print()
print(ca_df.describe())
print()
print(ca_df.info())
# Out:
#      state_code  state_name  county_code    county_name   aqi
# 76            6  California           37    Los Angeles  93.0
# 146           6  California           37    Los Angeles  59.0
# 41            6  California           83  Santa Barbara  47.0
# 122           6  California           59         Orange  47.0
# 184           6  California           59         Orange  47.0
#
#        state_code  county_code         aqi
# count       342.0   342.000000  342.000000
# mean          6.0    52.830409    9.412281
# std           0.0    28.751650    9.867579
# min           6.0     1.000000    0.000000
# 25%           6.0    29.000000    3.000000
# 50%           6.0    59.000000    6.000000
# 75%           6.0    73.000000   11.000000
# max           6.0   113.000000   93.000000
#
# <class 'pandas.core.frame.DataFrame'>
# Index: 342 entries, 76 to 56
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
# ...

# %%
ca2_df = top3_sorted[top3_sorted["state_name"] == "California"]
print(ca2_df.head())
# Out:
#      state_code  state_name  county_code    county_name   aqi
# 76            6  California           37    Los Angeles  93.0
# 146           6  California           37    Los Angeles  59.0
# 41            6  California           83  Santa Barbara  47.0
# 122           6  California           59         Orange  47.0
# 184           6  California           59         Orange  47.0

# %%
ca_df.shape
# Out:
# (342, 5)

# %%
ca_df["county_name"].value_counts()
# Out:
# county_name
# Los Angeles        55
# Santa Barbara      26
# San Bernardino     21
# Orange             19
# San Diego          19
# Sacramento         17
# Alameda            17
# Fresno             16
# Riverside          14
# Contra Costa       13
# Imperial           13
# San Francisco       8
# Monterey            8
# Humboldt            8
# Santa Clara         7
# El Dorado           7
# Placer              6
# Butte               6
# Kern                6
# Mendocino           6
# Solano              5
# San Joaquin         5
# Tulare              5
# Ventura             5
# Sutter              4
# San Mateo           4
# Marin               3
# Sonoma              3
# Stanislaus          3
# San Luis Obispo     2
# Napa                2
# Santa Cruz          2
# Calaveras           2
# Shasta              1
# Tuolumne            1
# Inyo                1
# Yolo                1
# Mono                1
# Name: count, dtype: int64

# %%
top3_grouped = top3.groupby('state_name')['aqi'].mean()

# %%
top3_grouped = top3.groupby('state_name')['aqi'].mean()

# %%
other_states = pd.read_csv('500_epa_others.csv')

# %%
other_states.head()
# Out:
#    state_code state_name  county_code county_name   aqi
# 0           4    Arizona           13    Maricopa  18.0
# 1           4    Arizona           13    Maricopa   9.0
# 2           4    Arizona           19        Pima  20.0
# 3           8   Colorado           41     El Paso   9.0
# 4          12    Florida           31       Duval  15.0

# %%
combined_df = pd.concat([top3, other_states], axis=0)
combined_df.head()
# Out:
#    state_code  state_name  county_code county_name   aqi
# 0           6  California            1     Alameda  11.0
# 1           6  California            7       Butte   6.0
# 2           6  California           19      Fresno  11.0
# 3           6  California           29        Kern   7.0
# 4           6  California           29        Kern   3.0

# %%
len(combined_df) == len(top3) + len(other_states)
# Out:
# True

# %%
mask = (combined_df['state_name'] == 'Washington') & (combined_df['aqi'] > 50)
combined_df[mask]
# Out:
#      state_code  state_name  county_code county_name   aqi
# 40           53  Washington           33        King  55.0
# 82           53  Washington           61   Snohomish  76.0
# 121          53  Washington           77      Yakima  58.0
# 122          53  Washington           77      Yakima  57.0
