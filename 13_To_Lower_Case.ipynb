# %% [markdown]
# <a href="https://colab.research.google.com/github/dkraynev/LeetCode/blob/main/13_To_Lower_Case.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Given a string s, return the string after replacing every uppercase letter with the same lowercase letter.
#
#
#
# Example 1:
#
# Input: s = "Hello"
# Output: "hello"
# Example 2:
#
# Input: s = "here"
# Output: "here"
# Example 3:
#
# Input: s = "LOVELY"
# Output: "lovely"

# %%
class Solution:
    def toLowerCase(self, s):
        return s.lower()
